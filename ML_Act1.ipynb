# %% [markdown]
# <a href="https://colab.research.google.com/github/Rakshikags/ML-Activities/blob/main/ML_Act1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Rakshika GS
#CH.SC.U4CSE23016
#ML Lab Activity 1

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('Salary_Data.csv')

# %%
#Exploring dataset
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
data.shape
# Out:
# (30, 2)

# %%
#Checking for any null values in dataset

data.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
#Assigning Dependent and Independent variables

x=data.iloc[:,:1].values
y=data.iloc[:, 1:2].values

# %%
#Splitting the dataset into Training and Testing Dataset

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
#Fitting the Model (Linear Regression)

model=LinearRegression()
model.fit(x_train, y_train)
y_pred=model.predict(x_test)

print(y_pred)
print(y_test)
# Out:
# [[115790.21011287]
#  [ 71498.27809463]
#  [102596.86866063]
#  [ 75267.80422384]
#  [ 55477.79204548]
#  [ 60189.69970699]]
# [[112635.]
#  [ 67938.]
#  [113812.]
#  [ 83088.]
#  [ 64445.]
#  [ 57189.]]

# %%
#Plot for Training dataset

plt.scatter(x_train, y_train, color='blue')
plt.plot(x_train, model.predict(x_train), color='red')
plt.title('SALARY vs EXPERIENCE (training set)')
plt.xlabel('Experience in Years')
plt.ylabel('Salary in Rupees')
plt.show()

# %%
#Plot for Testing dataset

plt.scatter(x_test, y_test, color='blue')
plt.plot(x_train, model.predict(x_train), color='red')
plt.title('SALARY vs EXPERIENCE (testing set)')
plt.xlabel('Experience in Years')
plt.ylabel('Salary in Rupees')
plt.show()

# %%
#Train a model to predict the fare of a taxi ride in Chicago, Illoinis

df=pd.read_csv('taxi.csv')
df.head()
# Out:
#                                     Trip ID  \
# 0  0287f53fedcde6b0af9aab9e32cbd2cadb337eaa
# 1  1f0034299b914fd7b45002568576a353c83acb2f
# 2  01a0b77b722a0b91f45cb4fc90b3e64f76fd0681
# 3  14aff2071ac81c6450a8f8b0e1534497da900197
# 4  16d3a633e2f380cee4a7fa4677db163b6e91255d
#
#                                              Taxi ID    Trip Start Timestamp  \
# 0  e54db25f18193a08f1f5754515e8c338480e04fb938ed3...  03/01/2024 12:00:00 AM
# 1  4a263f78f56815be4acd38658af8fc1824ce4e15f7ec81...  03/01/2024 12:00:00 AM
# 2  4f1e94982e6851725add382f7981d64006ae7c38f3664f...  03/01/2024 12:00:00 AM
# 3  de8e8659ceb9eb0da842a46b60c0a5207098ac69fc23ab...  03/01/2024 12:00:00 AM
# 4  d79d3e19a1d5f6cb0cd4449d5579412262a2f1b182799d...  03/01/2024 12:00:00 AM
#
#        Trip End Timestamp  Trip Seconds  Trip Miles  Pickup Census Tract  \
# 0  03/01/2024 12:00:00 AM          15.0        0.09                  NaN
# 1  03/01/2024 12:15:00 AM         900.0        3.00                  NaN
# 2  03/01/2024 12:00:00 AM         711.0        5.84                  NaN
# 3  03/01/2024 12:30:00 AM        1770.0       13.36                  NaN
# 4  03/01/2024 12:15:00 AM         849.0        6.13                  NaN
#
#    Dropoff Census Tract  Pickup Community Area  Dropoff Community Area  ...  \
# 0                   NaN                    8.0                     8.0  ...
# 1                   NaN                   24.0                     8.0  ...
# 2                   NaN                   56.0                     NaN  ...
# 3                   NaN                   76.0                     3.0  ...
# 4                   NaN                    8.0                     3.0  ...
#
#    Extras  Trip Total  Payment Type                    Company  \
# 0    35.0       38.75   Credit Card               City Service
# 1     0.0       12.00          Cash  Taxi Affiliation Services
# 2     5.0       26.70   Credit Card               City Service
# 3     4.0       47.10   Credit Card                   Sun Taxi
# 4     0.0       22.82        Mobile                5 Star Taxi
#
#    Pickup Centroid Latitude Pickup Centroid Longitude  \
# 0                 41.899602                -87.633308
# 1                 41.901207                -87.676356
# 2                 41.792592                -87.769615
# 3                 41.980264                -87.913625
# 4                 41.899602                -87.633308
#
#                Pickup Centroid Location  Dropoff Centroid Latitude  \
# 0   POINT (-87.6333080367 41.899602111)                  41.899602
# 1  POINT (-87.6763559892 41.9012069941)                  41.899602
# 2  POINT (-87.7696154528 41.7925923603)                        NaN
# 3   POINT (-87.913624596 41.9802643146)                  41.965812
# 4   POINT (-87.6333080367 41.899602111)                  41.965812
#
#    Dropoff Centroid Longitude           Dropoff Centroid  Location
# 0                  -87.633308  POINT (-87.6333080367 41.899602111)
# 1                  -87.633308  POINT (-87.6333080367 41.899602111)
# 2                         NaN                                  NaN
# 3                  -87.655879   POINT (-87.6558787862 41.96581197)
# 4                  -87.655879   POINT (-87.6558787862 41.96581197)
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (2567, 23)

# %%
df.isnull().sum()
# Out:
# Trip ID                          0
# Taxi ID                          0
# Trip Start Timestamp             1
# Trip End Timestamp               1
# Trip Seconds                     1
# Trip Miles                       1
# Pickup Census Tract           1906
# Dropoff Census Tract          1963
# Pickup Community Area           81
# Dropoff Community Area         333
# Fare                             4
# Tips                             4
# Tolls                            4
# Extras                           4
# Trip Total                       4
# Payment Type                     1
# Company                          1
# Pickup Centroid Latitude        81
# Pickup Centroid Longitude       81
# Pickup Centroid Location        81
# Dropoff Centroid Latitude      323
# Dropoff Centroid Longitude     323
# Dropoff Centroid  Location     323
# dtype: int64

# %%
df=df.dropna()
df.shape
# Out:
# (589, 23)

# %%
df=df[df['Trip Miles']>0]
df=df[df['Fare']>0]

# %%
x=df[['Trip Miles']]
y=df['Fare']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
model=LinearRegression()
model.fit(x_train, y_train)
y_pred=model.predict(x_test)

# %%
print(y_pred)
print(y_test)
# Out:
# [ 9.74841001 43.90259485 27.30159106 41.25305809 10.57639024  8.75483372
#  45.8069494  43.69559979  7.67845941 11.65276456 33.24234928 43.19881165
#  11.7976611  29.04034957 46.46933359 43.30230918  9.16882384  9.70701099
#  11.96325714 10.61778926 34.50501914 40.79766895 12.25305023  9.97610457
#   9.54141495 10.82478432 43.40580671 44.7719741  43.09531412 40.01108773
#  41.48075265 12.02535566 10.90758234 11.7976611  11.96325714  9.58281396
#  40.42507785 43.84049633  9.50001593  9.00322779  9.3758189   7.59566139
#   8.96182878 42.84692004 37.81694009 11.52856752 10.59708975 32.24877299
#  42.08103832 43.90259485 42.22593487  8.96182878 42.3294324  12.27374973
#  44.95826965 42.26733388  9.56211445  9.83120803  8.44434113  8.19594706
#  43.11601362  8.13384854 41.6670482  11.30087295 11.83906011 44.37868349
#  12.1495527  13.74341466 10.30729667 10.80408481 10.32799617 12.00465616
#   9.99680408 43.7369988  41.12886105 40.01108773 13.39152306  9.58281396
#  35.66419147  8.15454805 44.39938299  9.97610457 43.55070325 42.49502844
#  40.83906797 11.8183606  42.14313684  9.78980902 45.78624989 15.58567069
#   7.57496188  9.21022285 42.86761955 43.7369988   9.85190754  8.79623273
#  11.92185813  9.25162186 10.92828185 12.97753294  9.41721791]
# 2063     6.25
# 715     43.00
# 2107    29.25
# 1201    41.00
# 887      7.50
#         ...
# 787      9.25
# 738      5.75
# 2343     9.50
# 330     25.00
# 1607    10.00
# Name: Fare, Length: 101, dtype: float64

# %%
plt.scatter(x_train, y_train, color='orange', edgecolor='black')
plt.plot(x_train, model.predict(x_train), color='green')
plt.title('FARE vs TRIP MILES (training set)')
plt.xlabel('Trip Miles')
plt.ylabel('Fare')
plt.show()

# %%
plt.scatter(x_test, y_test, color='orange', edgecolor='black')
plt.plot(x_train, model.predict(x_train), color='green')
plt.title('FARE vs TRIP MILES (testing set)')
plt.xlabel('Trip Miles')
plt.ylabel('Fare')
plt.show()
